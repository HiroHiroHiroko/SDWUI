# %% [markdown]
# <a href="https://colab.research.google.com/github/HiroHiroHiroko/stable-diffusion-webui/blob/master/yesmix_v15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade Pillow
# !echo "Y" | pip uninstall torchvision
# !echo "Y" | pip install torchvision==1.9.0

# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd /content/stable-diffusion-webui

# !wget https://huggingface.co/hirohironog/Model/resolve/main/yesmix_v15.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/yesmix_v15.safetensors
# !wget https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -O /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: Skipping torchvision as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement torchvision==1.9.0 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.8.2, 0.9.0, 0.9.1, 0.10.0, 0.10.1, 0.11.0, 0.11.1, 0.11.2, 0.11.3, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1)
# ERROR: No matching distribution found for torchvision==1.9.0
# fatal: destination path 'stable-diffusion-webui' already exists and is not an empty directory.
# /content/stable-diffusion-webui
# --2023-04-06 07:40:59--  https://huggingface.co/hirohironog/Model/resolve/main/yesmix_v15.safetensors
# Resolving huggingface.co (huggingface.co)... 18.67.0.55, 18.67.0.34, 18.67.0.67, ...
# ...

# %%
# !python launch.py --share --xformers --enable-insecure-extension-access
# Out:
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Installing torch and torchvision
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu117
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 946.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 44.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0
#     Uninstalling torch-2.0.0:
#       Successfully uninstalled torch-2.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.13.1+cu117 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.13.1+cu117 which is incompatible.
# ...

# %%
# !wget https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Korean-doll-likeness.safetensors -O /content/stable-diffusion-webui/models/Lora/Korean-doll-likeness.safetensors
# !wget https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Japanese-doll-likeness.safetensors -O /content/stable-diffusion-webui/models/Lora/Japanese-doll-likeness.safetensors
# !wget https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Taiwan-doll-likeness.safetensors -O /content/stable-diffusion-webui/models/Lora/Taiwan-doll-likeness.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/darkMagicianGirlLora_1.safetensors -O /content/stable-diffusion-webui/models/Lora/darkMagicianGirlLora_1.safetensors 
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/makimaChainsawMan_offset.safetensors -O /content/stable-diffusion-webui/models/Lora/makimaChainsawMan_offset.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/mitsurikanrojilora_v1.safetensors -O /content/stable-diffusion-webui/models/Lora/mitsurikanrojilora_v1.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/povDoggystyleLora1MB_povdoggy.safetensors -O /content/stable-diffusion-webui/models/Lora/povDoggystyleLora1MB_povdoggy.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/povSquattingCowgirlLora_pscowgirl.safetensors -O /content/stable-diffusion-webui/models/Lora/povSquattingCowgirlLora_pscowgirl.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/princessZeldaLora_v1.safetensors  -O /content/stable-diffusion-webui/models/Lora/princessZeldaLora_v1.safetensors
# !wget https://huggingface.co/HiroHiroHirook/LoRA/resolve/main/EasyNegative.safetensors -O /content/stable-diffusion-webui/embeddings/EasyNegative.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/yorBriarSpyFamily_lykonV1.safetensors -O /content/stable-diffusion-webui/models/Lora/yorBriarSpyFamily_lykonV1.safetensors
# Out:
# --2023-04-06 07:45:33--  https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Korean-doll-likeness.safetensors
# Resolving huggingface.co (huggingface.co)... 18.67.0.34, 18.67.0.67, 18.67.0.55, ...
# Connecting to huggingface.co (huggingface.co)|18.67.0.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Korean-doll-likeness.safetensors -O /content/stable-diffusion-webui/models/Lora/Korean-doll-likeness.safetensors
# !wget https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Korean-doll-likeness.safetensors -O /content/stable-diffusion-webui/models/Lora/Korean-doll-likeness.safetensors
# !wget https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Japanese-doll-likeness.safetensors -O /content/stable-diffusion-webui/models/Lora/Japanese-doll-likeness.safetensors
# !wget https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Taiwan-doll-likeness.safetensors -O /content/stable-diffusion-webui/models/Lora/Taiwan-doll-likeness.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/darkMagicianGirlLora_1.safetensors -O /content/stable-diffusion-webui/models/Lora/darkMagicianGirlLora_1.safetensors 
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/makimaChainsawMan_offset.safetensors -O /content/stable-diffusion-webui/models/Lora/makimaChainsawMan_offset.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/mitsurikanrojilora_v1.safetensors -O /content/stable-diffusion-webui/models/Lora/mitsurikanrojilora_v1.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/povDoggystyleLora1MB_povdoggy.safetensors -O /content/stable-diffusion-webui/models/Lora/povDoggystyleLora1MB_povdoggy.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/povSquattingCowgirlLora_pscowgirl.safetensors -O /content/stable-diffusion-webui/models/Lora/povSquattingCowgirlLora_pscowgirl.safetensors   
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/princessZeldaLora_v1.safetensors  -O /content/stable-diffusion-webui/models/Lora/princessZeldaLora_v1.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/EasyNegative.safetensors -O /content/stable-diffusion-webui/embeddings/EasyNegative.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/pokemonLillieLilieSD15_v4.safetensors  -O /content/stable-diffusion-webui/models/Lora/pokemonLillieLilieSD15_v4.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/soniaPokemonSSLora_pokesonia.safetensors  -O /content/stable-diffusion-webui/models/Lora/soniaPokemonSSLora_pokesonia.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/pokemonNessaRurinaSD15_v5.safetensors  -O /content/stable-diffusion-webui/models/Lora/pokemonNessaRurinaSD15_v5.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/marniePokemonSSLora8_pokemarnie.safetensors  -O /content/stable-diffusion-webui/models/Lora/marniePokemonSSLora8_pokemarnie.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/chizuruMizuharaRentA_iCantBelieveMy.safetensors -O /content/stable-diffusion-webui/models/Lora/chizuruMizuharaRentA_iCantBelieveMy.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/actressSatomi_v10.safetensors -O /content/stable-diffusion-webui/models/Lora/actressSatomi_v10.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/femaleMasturbation_v1.safetensors -O /content/stable-diffusion-webui/models/Lora/femaleMasturbation_v1.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/orgasmFace_v10.safetensors -O /content/stable-diffusion-webui/models/Lora/orgasmFace_v10.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/saikaKawakita_saikaV30.safetensors -O /content/stable-diffusion-webui/models/Lora/saikaKawakita_saikaV30.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/saikaKawakitaTifa_saikaKawakitaTifa.safetensors -O /content/stable-diffusion-webui/models/Lora/saikaKawakitaTifa_saikaKawakitaTifa.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/yorBriarSpyFamily_lykonV1.safetensors -O /content/stable-diffusion-webui/models/Lora/yorBriarSpyFamily_lykonV1.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/mitsuriDemonSlayerLORA_v1.safetensors -O /content/stable-diffusion-webui/models/Lora/mitsuriDemonSlayerLORA_v1.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/bukkakeLora_v10.safetensors -O /content/stable-diffusion-webui/models/Lora/bukkakeLora_v10.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/murkysAfterSexLying_1.safetensors -O /content/stable-diffusion-webui/models/Lora/murkysAfterSexLying_1.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/shinobuKochouDemon_v10.safetensors -O /content/stable-diffusion-webui/models/Lora/shinobuKochouDemon_v10.safetensors
# !wget https://huggingface.co/hirohironog/LoRA/resolve/main/bad_prompt_version2.pt -O /content/stable-diffusion-webui/embeddings/bad_prompt_version2.pt
# Out:
# --2023-04-06 07:46:03--  https://huggingface.co/hirohironog/chilloutmix_NiPrunedFp32Fix/resolve/main/Korean-doll-likeness.safetensors
# Resolving huggingface.co (huggingface.co)... 18.67.0.67, 18.67.0.90, 18.67.0.34, ...
# Connecting to huggingface.co (huggingface.co)|18.67.0.67|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python launch.py --share --xformers --enable-insecure-extension-access
# Out:
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: 22bcc7be428c94e9408f589966c2040187245d81
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --xformers --enable-insecure-extension-access
# 2023-04-06 07:57:51.314166: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 07:57:53.660980: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading weights [f713bab753] from /content/stable-diffusion-webui/models/Stable-diffusion/yesmix_v15.safetensors
# Creating model from config: /content/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# ...
